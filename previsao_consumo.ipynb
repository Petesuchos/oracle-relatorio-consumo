# %%
import pandas as pd
import numpy as np

# %%
def previsao_consumo_diario(data_inicio, 
                            data_fim, 
                            dias_rampa, 
                            valor_arr, 
                            cliente, 
                            oportunidade = '',
                            tipo_forecast = '', 
                            pct_inicial_rampa=0.01, 
                            pct_final_rampa=0.90):
    idx = pd.date_range(data_inicio, data_fim)
    ramp_linspace = np.linspace(start=pct_inicial_rampa, stop=pct_final_rampa, num=dias_rampa)
    
    if len(idx) - dias_rampa >= 0:
        ramp_array = np.append(ramp_linspace, np.ones(len(idx) - dias_rampa))
    else:
        ramp_array = ramp_linspace[0: len(idx)]
    
    valor_diario = valor_arr / 365
    previsao_consumo_array = valor_diario * ramp_array
    
    df = pd.DataFrame(
        {
            'Consumo USD': previsao_consumo_array,
            'Cliente': cliente,
            'Oportunidade': oportunidade,
            'Tipo Forecast': tipo_forecast
        },
        index=idx
    )
    df.index.name = 'Data'
    
    return df

# %%
oportunidades = [
    {
        'data_inicio': '2021-06-01',
        'data_fim': '2022-05-31',
        'dias_rampa': 0,
        'valor_arr': 92_089.0,
        'cliente': 'BBTS',
        'oportunidade': 'BBTS ExaCC',
        'tipo_forecast': 'Forecast',
    },
    
    {
        'data_inicio': '2021-06-01',
        'data_fim': '2022-05-31',
        'dias_rampa': 0,
        'valor_arr': 57_200.0,
        'cliente': 'Ativos',
        'oportunidade': 'Ativos DevOps',
        'tipo_forecast': 'Forecast',
    },
    
    {
        'data_inicio': '2021-07-23',
        'data_fim': '2022-05-31',
        'dias_rampa': 0,
        'valor_arr': 93_014.0,
        'cliente': 'BBTS',
        'oportunidade': 'BBTS EBS Dev',
        'tipo_forecast': 'Forecast',
    },
    
    {
        'data_inicio': '2021-11-01',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 600_000.0,
        'cliente': 'BrasilCap',
        'oportunidade': 'BrasilCap Cloud',
        'tipo_forecast': 'Forecast',
    },
    
    {
        'data_inicio': '2021-12-01',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 233_241.0,
        'cliente': 'BBTS',
        'oportunidade': 'BBTS PSIM DR',
        'tipo_forecast': 'Upside',
    },
    
    {
        'data_inicio': '2021-12-07',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 50_034.0,
        'cliente': 'Ativos',
        'oportunidade': 'Ativos BD',
        'tipo_forecast': 'Pipeline',
    },
    
    {
        'data_inicio': '2022-01-11',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 31_036.0,
        'cliente': 'BBTS',
        'oportunidade': 'BBTS DevOps',
        'tipo_forecast': 'Pipeline',
    },
    
    {
        'data_inicio': '2022-02-02',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 200_000.0,
        'cliente': 'CASSI',
        'oportunidade': 'CASSI DR BENNER',
        'tipo_forecast': 'Pipeline',
    },
    
    {
        'data_inicio': '2022-02-02',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 233_241.0,
        'cliente': 'BBTS',
        'oportunidade': 'BBTS PSIM Site Principal',
        'tipo_forecast': 'Pipeline',
    },
    
    {
        'data_inicio': '2022-02-02',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 25_769.0,
        'cliente': 'BBTS',
        'oportunidade': 'BBTS Winback Postgres',
        'tipo_forecast': 'Pipeline',
    },
    
    {
        'data_inicio': '2022-02-02',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 240_000.0,
        'cliente': 'BrasilPrev',
        'oportunidade': 'BrasilPrev DBCS',
        'tipo_forecast': 'Pipeline',
    },

    {
        'data_inicio': '2022-02-04',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 79_002.0,
        'cliente': 'Ativos',
        'oportunidade': 'Ativos BI Cloud',
        'tipo_forecast': 'Pipeline',
    },

    {
        'data_inicio': '2022-02-08',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 198_254.0,
        'cliente': 'BBTS',
        'oportunidade': 'BBTS OCC',
        'tipo_forecast': 'Pipeline',
    },

    {
        'data_inicio': '2022-03-01',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 200_000.0,
        'cliente': 'BB',
        'oportunidade': 'BB MySQL Heatwave',
        'tipo_forecast': 'Pipeline',
    },
    
    {
        'data_inicio': '2022-03-02',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 200_000.0,
        'cliente': 'BB',
        'oportunidade': 'BB AI para serviços bancários',
        'tipo_forecast': 'Pipeline',
    },
    
    {
        'data_inicio': '2022-03-11',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 100_000.0,
        'cliente': 'BB Seguridade',
        'oportunidade': 'BB Seg Amazon Attack',
        'tipo_forecast': 'Pipeline',
    },

    {
        'data_inicio': '2022-03-15',
        'data_fim': '2022-05-31',
        'dias_rampa': 90,
        'valor_arr': 100_000.0,
        'cliente': 'PREVI',
        'oportunidade': 'PREVI Move to Cloud',
        'tipo_forecast': 'Pipeline',
    },
]

# %%
lista_previsoes = [previsao_consumo_diario(**op) for op in oportunidades]

# %%
previsoes_df = pd.concat(lista_previsoes)

# %%
previsoes_df
# Out:
#             Consumo USD Cliente         Oportunidade Tipo Forecast
# Data
# 2021-06-01   252.298630    BBTS           BBTS ExaCC      Forecast
# 2021-06-02   252.298630    BBTS           BBTS ExaCC      Forecast
# 2021-06-03   252.298630    BBTS           BBTS ExaCC      Forecast
# 2021-06-04   252.298630    BBTS           BBTS ExaCC      Forecast
# 2021-06-05   252.298630    BBTS           BBTS ExaCC      Forecast
# ...                 ...     ...                  ...           ...
# 2022-05-27   202.739726   PREVI  PREVI Move to Cloud      Pipeline
# 2022-05-28   205.479452   PREVI  PREVI Move to Cloud      Pipeline
# 2022-05-29   208.219178   PREVI  PREVI Move to Cloud      Pipeline
# 2022-05-30   210.958904   PREVI  PREVI Move to Cloud      Pipeline
# 2022-05-31   213.698630   PREVI  PREVI Move to Cloud      Pipeline
#
# [2803 rows x 4 columns]

# %%
with pd.ExcelWriter('Previsão de Consumo.xlsx') as writer:
    previsoes_df.to_excel(writer, sheet_name='Previsão de Consumo')
