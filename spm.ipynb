# %% [markdown]
# # SPM
#
# Arquivos SPM contém os dados de consumo de um determinado cliente

# %%
import pandas as pd
import glob

# %% [markdown]
# Configurando a precisão do pandas para 2 casa decimais

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
# Dicionário de data types
_spm_dtype_dict = {
    "Subs. Service Line No.": str,
    "Compute Type": str,
    "Active": str,
    "Usage Line Number": float,
    # "Metered service date": np.datetime64,
    "Sub Account": float,
    "Computed Quantity": float,
    "Existing Entitled Qty": float,
    "Usage Quantity": float,
    "UOM": str,
    "Product": str,
    "Parent Product": str,
    "Net Unit Price": float,
    "SPM Document Number": str,
    "Line Net Amount": float,
    "Bill To Plan Number": float,
    "Consumed Quantity": float,
    "Overage": str,
    "Compute Source": float,
    "Status": str,
    "Available Amt After Computing": float,
    "Is Credit Memo?": str,
    "Spm Partner Credit Amt": float,
    "Bill to Customer": str,
    "Trxn Extension ID": float,
    "Line Net Amount Increased Precision": float,
    "UCM Payment Credit Amt": float,
}

# %% [markdown]
# Os arquivos com os dados brutos do SPM estão localizados na pasta `consumption_data` em formato CSV.
#
# Vamos criar uma lista com todos esses aquivos.

# %%
csv_data_files = [file for file in glob.glob('./consumption_data/*.csv')]
csv_data_files
# Out:
# ['./consumption_data\\ativos_0621.csv',
#  './consumption_data\\ativos_0721.csv',
#  './consumption_data\\ativos_0821.csv',
#  './consumption_data\\ativos_0921.csv',
#  './consumption_data\\ativos_1021.csv',
#  './consumption_data\\bbts_0621.csv',
#  './consumption_data\\bbts_0721.csv',
#  './consumption_data\\bbts_0821.csv',
#  './consumption_data\\bbts_0921.csv',
#  './consumption_data\\bbts_1021.csv']

# %% [markdown]
# Criando os dataframes a partir dos arquivos CSV

# %%
col_list = ['Computed Quantity', 'Metered service date', 'UOM', 'Product', 'Net Unit Price', 'Line Net Amount', 'Bill to Customer']
dataframes_list = [
    pd.read_csv(csv_file, dtype=_spm_dtype_dict, parse_dates=["Metered service date"], usecols=col_list)[:-1] 
    for csv_file in csv_data_files
]
df = pd.concat(dataframes_list)
df.head()
# Out:
#   Metered service date  Computed Quantity        UOM  \
# 0           2021-06-17               1.00  PORT HOUR
# 1           2021-06-19               1.00  PORT HOUR
# 2           2021-06-16               1.00  PORT HOUR
# 3           2021-06-07               1.00  PORT HOUR
# 4           2021-06-02               1.00  PORT HOUR
#
#                                              Product  Net Unit Price  \
# 0  B88326 - Oracle Cloud Infrastructure - FastCon...            5.38
# 1  B88326 - Oracle Cloud Infrastructure - FastCon...            5.38
# 2  B88326 - Oracle Cloud Infrastructure - FastCon...            5.38
# 3  B88326 - Oracle Cloud Infrastructure - FastCon...            5.38
# 4  B88326 - Oracle Cloud Infrastructure - FastCon...            5.38
#
#    Line Net Amount                                 Bill to Customer
# 0             5.38  15820392 - Netmanagement Informatica Ltda - Epp
# 1             5.38  15820392 - Netmanagement Informatica Ltda - Epp
# 2             5.38  15820392 - Netmanagement Informatica Ltda - Epp
# 3             5.38  15820392 - Netmanagement Informatica Ltda - Epp
# 4             5.38  15820392 - Netmanagement Informatica Ltda - Epp

# %% [markdown]
# Removendo as linhas com créditos não utilizados na modalidade funded allocation

# %%
df = df[df["UOM"] != "CURRENCY UNIT"]
# Uma alternativa a sintaxe acima poderia ser
# df.drop(df.loc[df["UOM"] == "CURRENCY UNIT"].index, inplace=True)

# %% [markdown]
# Expandindo as colunas

# %%
df[['PartNumber', 'Categoria Produto', 'Produto']] = df['Product'].str.split(pat=" - ", n=2, expand=True)
df[['Numero Cliente', 'Cliente']] = df['Bill to Customer'].str.split(pat='-', n=1, expand=True)
df.drop(labels=['Product', 'Bill to Customer'], axis=1, inplace=True)

# %% [markdown]
# Renomeando as colunas

# %%
df.rename(columns={"Metered service date": "Data",
                   "Computed Quantity": "Quantidade",
                   "UOM": "Unidade de Medida",
                   "Net Unit Price": "Preco Unitario BRL",
                   "Line Net Amount":"Consumo BRL"},
          inplace=True)

# %% [markdown]
# Criando o campo calculado `Consumo USD`

# %%
df['Consumo USD'] = df['Consumo BRL'] / 5.31

# %% [markdown]
# Colocando a `Data` como o índice do dataframe

# %%
df.set_index('Data', inplace=True)

# %%
df.head()
# Out:
#             Quantidade Unidade de Medida  Preco Unitario BRL  Consumo BRL  \
# Data
# 2021-06-17        1.00         PORT HOUR                5.38         5.38
# 2021-06-19        1.00         PORT HOUR                5.38         5.38
# 2021-06-16        1.00         PORT HOUR                5.38         5.38
# 2021-06-07        1.00         PORT HOUR                5.38         5.38
# 2021-06-02        1.00         PORT HOUR                5.38         5.38
#
#            PartNumber            Categoria Produto  \
# Data
# 2021-06-17     B88326  Oracle Cloud Infrastructure
# 2021-06-19     B88326  Oracle Cloud Infrastructure
# 2021-06-16     B88326  Oracle Cloud Infrastructure
# 2021-06-07     B88326  Oracle Cloud Infrastructure
# 2021-06-02     B88326  Oracle Cloud Infrastructure
#
#                                     Produto Numero Cliente  \
# Data
# 2021-06-17  FastConnect 10 Gbps - Port Hour      15820392
# 2021-06-19  FastConnect 10 Gbps - Port Hour      15820392
# 2021-06-16  FastConnect 10 Gbps - Port Hour      15820392
# 2021-06-07  FastConnect 10 Gbps - Port Hour      15820392
# 2021-06-02  FastConnect 10 Gbps - Port Hour      15820392
#
#                                           Cliente  Consumo USD
# Data
# 2021-06-17   Netmanagement Informatica Ltda - Epp         1.01
# 2021-06-19   Netmanagement Informatica Ltda - Epp         1.01
# 2021-06-16   Netmanagement Informatica Ltda - Epp         1.01
# 2021-06-07   Netmanagement Informatica Ltda - Epp         1.01
# 2021-06-02   Netmanagement Informatica Ltda - Epp         1.01

# %% [markdown]
# Reordenando as colunas

# %%
df.columns
# Out:
# Index(['Quantidade', 'Unidade de Medida', 'Preco Unitario BRL', 'Consumo BRL',
#        'PartNumber', 'Categoria Produto', 'Produto', 'Numero Cliente',
#        'Cliente', 'Consumo USD'],
#       dtype='object')

# %%
df = df[['Numero Cliente', 'Cliente','PartNumber', 'Categoria Produto', 'Produto', 'Unidade de Medida', 'Quantidade', 'Preco Unitario BRL', 'Consumo BRL', 'Consumo USD']]
df.head()
# Out:
#            Numero Cliente                                Cliente PartNumber  \
# Data
# 2021-06-17      15820392    Netmanagement Informatica Ltda - Epp     B88326
# 2021-06-19      15820392    Netmanagement Informatica Ltda - Epp     B88326
# 2021-06-16      15820392    Netmanagement Informatica Ltda - Epp     B88326
# 2021-06-07      15820392    Netmanagement Informatica Ltda - Epp     B88326
# 2021-06-02      15820392    Netmanagement Informatica Ltda - Epp     B88326
#
#                       Categoria Produto                          Produto  \
# Data
# 2021-06-17  Oracle Cloud Infrastructure  FastConnect 10 Gbps - Port Hour
# 2021-06-19  Oracle Cloud Infrastructure  FastConnect 10 Gbps - Port Hour
# 2021-06-16  Oracle Cloud Infrastructure  FastConnect 10 Gbps - Port Hour
# 2021-06-07  Oracle Cloud Infrastructure  FastConnect 10 Gbps - Port Hour
# 2021-06-02  Oracle Cloud Infrastructure  FastConnect 10 Gbps - Port Hour
#
#            Unidade de Medida  Quantidade  Preco Unitario BRL  Consumo BRL  \
# Data
# 2021-06-17         PORT HOUR        1.00                5.38         5.38
# 2021-06-19         PORT HOUR        1.00                5.38         5.38
# 2021-06-16         PORT HOUR        1.00                5.38         5.38
# 2021-06-07         PORT HOUR        1.00                5.38         5.38
# 2021-06-02         PORT HOUR        1.00                5.38         5.38
#
#             Consumo USD
# Data
# 2021-06-17         1.01
# 2021-06-19         1.01
# 2021-06-16         1.01
# 2021-06-07         1.01
# 2021-06-02         1.01

# %% [markdown]
# Ordenando o dataframe

# %%
df = df.sort_index()

# %% [markdown]
# Salvando

# %%
with pd.ExcelWriter('Relatório de Consumo.xlsx') as writer:
    df.to_excel(writer, sheet_name='Dados de Consumo')
