# %%
from diagrams import Diagram

# %%
from diagrams.oci.compute import AutoscaleWhite, Autoscale, BMWhite, BM, ContainerWhite, Container, FunctionsWhite, Functions, InstancePoolsWhite, InstancePools, OCIRWhite, OCIR, OKEWhite, OKE, VMWhite, VM

# %%
with Diagram("OCI", show=False, direction='BT') as diag:
    Autoscale('Autoscale') >> BM('Bare Metal')
    Container('Container')
    Functions('Functions')
    InstancePools('Instance Pools')
    OCIR('OCIR')
    OKE('OKE')
    VM('VM')
diag

# %%
with Diagram("OCI", show=False, direction='BT') as diag:
    Autoscale('Autoscale') >> BM('Bare Metal')
    Container('Container')
    Functions('Functions')
    InstancePools('Instance Pools')
    OCIR('OCIR')
    OKE('OKE')
    VM('VM')
diag
