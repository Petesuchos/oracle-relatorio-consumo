# %%
import pandas as pd

# %%
df = pd.read_excel('Lista de Oportunidades.xlsx')

# %%
df
# Out:
#    data_inicio   data_fim  dias_rampa  valor_arr        cliente  \
# 0   2021-06-01 2022-05-31          90      90089           BBTS
# 1   2021-06-01 2022-05-31          90      57200         Ativos
# 2   2021-07-30 2022-05-31          90      93014           BBTS
# 3   2021-11-01 2022-05-31          90     600000      BrasilCap
# 4   2021-12-01 2022-05-31          90     233241           BBTS
# 5   2021-12-07 2022-05-31          90      50034         Ativos
# 6   2022-01-11 2022-05-31          90      31036           BBTS
# 7   2022-02-02 2022-05-31          90     200000          CASSI
# 8   2022-02-02 2022-05-31          90     233241           BBTS
# 9   2022-02-02 2022-05-31          90      25769           BBTS
# 10  2022-02-02 2022-05-31          90     240000     BrasilPrev
# 11  2022-02-04 2022-05-31          90      79002         Ativos
# 12  2022-02-08 2022-05-31          90     198254           BBTS
# 13  2022-03-01 2022-05-31          90     200000             BB
# ...

# %%
df.to_dict(orient='records')
# Out:
# [{'data_inicio': Timestamp('2021-06-01 00:00:00'),
#   'data_fim': Timestamp('2022-05-31 00:00:00'),
#   'dias_rampa': 90,
#   'valor_arr': 90089,
#   'cliente': 'BBTS',
#   'oportunidade': 'BBTS ExaCC',
#   'tipo_forecast': 'Forecast'},
#  {'data_inicio': Timestamp('2021-06-01 00:00:00'),
#   'data_fim': Timestamp('2022-05-31 00:00:00'),
#   'dias_rampa': 90,
#   'valor_arr': 57200,
#   'cliente': 'Ativos',
#   'oportunidade': 'Ativos DevOps',
#   'tipo_forecast': 'Forecast'},
#  {'data_inicio': Timestamp('2021-07-30 00:00:00'),
#   'data_fim': Timestamp('2022-05-31 00:00:00'),
#   'dias_rampa': 90,
#   'valor_arr': 93014,
#   'cliente': 'BBTS',
#   'oportunidade': 'BBTS EBS Dev',
#   'tipo_forecast': 'Forecast'},
#  {'data_inicio': Timestamp('2021-11-01 00:00:00'),
#   'data_fim': Timestamp('2022-05-31 00:00:00'),
#   'dias_rampa': 90,
#   'valor_arr': 600000,
#   'cliente': 'BrasilCap',
#   'oportunidade': 'BrasilCap Multicloud',
#   'tipo_forecast': 'Forecast'},
# ...
