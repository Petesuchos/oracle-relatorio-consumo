# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date, timedelta

# %matplotlib inline

# %%
_dtype_dict = {
    "Subs. Service Line No.": str,
    "Compute Type": str,
    "Active": str,
    "Usage Line Number": float,
    # "Metered service date": np.datetime64,
    "Sub Account": float,
    "Computed Quantity": float,
    "Existing Entitled Qty": float,
    "Usage Quantity": float,
    "UOM": str,
    "Product": str,
    "Parent Product": str,
    "Net Unit Price": float,
    "SPM Document Number": str,
    "Line Net Amount": float,
    "Bill To Plan Number": float,
    "Consumed Quantity": float,
    "Overage": str,
    "Compute Source": float,
    "Status": str,
    "Available Amt After Computing": float,
    "Is Credit Memo?": str,
    "Spm Partner Credit Amt": float,
    "Bill to Customer": str,
    "Trxn Extension ID": float,
    "Line Net Amount Increased Precision": float,
    "UCM Payment Credit Amt": float,
}

# %%
cols_list = ["Computed Quantity", "Metered service date", "UOM", "Product", "Net Unit Price", "Line Net Amount", "Status", "Bill to Customer"]

# %%
with open("./BBTS.csv") as csvfile:
    # df = pd.read_csv(csvfile, parse_dates=["Metered service date"], dtype=_dtype_dict)[:-1]
    df = pd.read_csv(csvfile, parse_dates=["Metered service date"], dtype=_dtype_dict, usecols=cols_list)[:-1]
    df.rename(columns={"Metered service date": "Data",
                       "Computed Quantity": "Quantidade",
                       "UOM": "Unidade de Medida",
                       "Product": "Produto",
                       "Net Unit Price": "Preco Unitario BRL",
                       "Line Net Amount":"Consumo BRL",
                       "Bill to Customer": "Cliente"},
              inplace=True)
    df.set_index("Data", inplace=True)
    df["Consumo USD"] = df["Consumo BRL"] / 5.27

# %%
agosto = df.loc["2021-08-01":"2021-08-31"]

# %%
agosto
# Out:
#             Quantidade    Unidade de Medida  \
# Data
# 2021-08-01     1.00000        OCPU PER HOUR
# 2021-08-02     1.00000        OCPU PER HOUR
# 2021-08-01     1.00000        OCPU PER HOUR
# 2021-08-02     1.00000        OCPU PER HOUR
# 2021-08-01     1.00000        OCPU PER HOUR
# ...                ...                  ...
# 2021-08-05    73.23764  PERF UN PR GB PR MO
# 2021-08-23     7.83442  PERF UN PR GB PR MO
# 2021-08-09    73.23764  PERF UN PR GB PR MO
# 2021-08-29    86.35957  PERF UN PR GB PR MO
# 2021-08-26    51.14862  PERF UN PR GB PR MO
#
#                                                       Produto  \
# Data
# 2021-08-01  B90572 - Oracle Cloud Infrastructure - Databas...
# 2021-08-02  B90572 - Oracle Cloud Infrastructure - Databas...
# 2021-08-01  B90572 - Oracle Cloud Infrastructure - Databas...
# 2021-08-02  B90572 - Oracle Cloud Infrastructure - Databas...
# 2021-08-01  B90572 - Oracle Cloud Infrastructure - Databas...
# ...                                                       ...
# 2021-08-05  B91962 - Oracle Cloud Infrastructure - Block V...
# 2021-08-23  B91962 - Oracle Cloud Infrastructure - Block V...
# 2021-08-09  B91962 - Oracle Cloud Infrastructure - Block V...
# 2021-08-29  B91962 - Oracle Cloud Infrastructure - Block V...
# 2021-08-26  B91962 - Oracle Cloud Infrastructure - Block V...
#
#             Preco Unitario BRL  Consumo BRL  \
# Data
# 2021-08-01              5.0153         5.02
# 2021-08-02              5.0153         5.02
# 2021-08-01              5.0153         5.02
# 2021-08-02              5.0153         5.02
# 2021-08-01              5.0153         5.02
# ...                        ...          ...
# 2021-08-05              0.0051         0.37
# 2021-08-23              0.0051         0.04
# 2021-08-09              0.0051         0.37
# 2021-08-29              0.0051         0.44
# 2021-08-26              0.0051         0.26
#
#                                        Status  \
# Data
# 2021-08-01                   Invoiced | Draft
# 2021-08-02                   Invoiced | Draft
# 2021-08-01                   Invoiced | Draft
# 2021-08-02                   Invoiced | Draft
# 2021-08-01                   Invoiced | Draft
# ...                                       ...
# 2021-08-05  Invoiced | Awaiting to send to AR
# 2021-08-23  Invoiced | Awaiting to send to AR
# 2021-08-09  Invoiced | Awaiting to send to AR
# 2021-08-29  Invoiced | Awaiting to send to AR
# 2021-08-26  Invoiced | Awaiting to send to AR
#
#                                             Cliente  Consumo USD
# Data
# 2021-08-01  10208161 - Bb Tecnologia E Servicos S.A     0.952562
# 2021-08-02  10208161 - Bb Tecnologia E Servicos S.A     0.952562
# 2021-08-01  10208161 - Bb Tecnologia E Servicos S.A     0.952562
# 2021-08-02  10208161 - Bb Tecnologia E Servicos S.A     0.952562
# 2021-08-01  10208161 - Bb Tecnologia E Servicos S.A     0.952562
# ...                                             ...          ...
# 2021-08-05  10208161 - Bb Tecnologia E Servicos S.A     0.070209
# 2021-08-23  10208161 - Bb Tecnologia E Servicos S.A     0.007590
# 2021-08-09  10208161 - Bb Tecnologia E Servicos S.A     0.070209
# 2021-08-29  10208161 - Bb Tecnologia E Servicos S.A     0.083491
# 2021-08-26  10208161 - Bb Tecnologia E Servicos S.A     0.049336
#
# [6319 rows x 8 columns]

# %%
agosto.to_excel("bbts_agosto.xlsx")
